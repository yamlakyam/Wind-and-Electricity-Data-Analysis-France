# %%
import warnings
# importing libraries 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

warnings.filterwarnings('ignore')

# %% [markdown]
# # Weather Data

# %%
#reading the csv dataset
weather_df = pd.read_csv('Paris_weather_data_2017.csv', encoding = 'unicode_escape')
weather_df
# Out:
#            Date  high Temp. (°C)  avg Temp. (°C)  low Temp. (°C)  \
# 0      1/1/2017                0              -3              -5
# 1      1/2/2017                2               0              -2
# 2      1/3/2017                1               0              -1
# 3      1/4/2017                6               2              -1
# 4      1/5/2017                7               3               1
# ..          ...              ...             ...             ...
# 360  12/27/2017                6               4               3
# 361  12/28/2017                6               2              -1
# 362  12/29/2017                8               3              -1
# 363  12/30/2017               14              10               6
# 364  12/31/2017               15              12               9
#
#      high Dew Point (°C)  avg Dew Point (°C)  low Dew Point (°C)  \
# 0                     -1                  -3                  -6
# ...

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         365 non-null    object
#  1   high Temp. (°C)              365 non-null    int64
#  2   avg Temp. (°C)               365 non-null    int64
#  3   low Temp. (°C)               365 non-null    int64
#  4   high Dew Point (°C)          365 non-null    int64
#  5   avg Dew Point (°C)           365 non-null    int64
#  6   low Dew Point (°C)           365 non-null    int64
#  7   high Humidity (%)            365 non-null    int64
#  8   avg Humidity (%)             365 non-null    int64
#  9   low Humidity (%)             365 non-null    int64
#  10  high Sea Level Press. (hPa)  365 non-null    int64
#  11  avg Sea Level Press. (hPa)   365 non-null    int64
#  12  low Sea Level Press. (hPa)   365 non-null    int64
# ...

# %%
#checking for null values in the columns
weather_df.isnull().sum()
# Out:
# Date                             0
# high Temp. (°C)                  0
# avg Temp. (°C)                   0
# low Temp. (°C)                   0
# high Dew Point (°C)              0
# avg Dew Point (°C)               0
# low Dew Point (°C)               0
# high Humidity (%)                0
# avg Humidity (%)                 0
# low Humidity (%)                 0
# high Sea Level Press. (hPa)      0
# avg Sea Level Press. (hPa)       0
# low Sea Level Press. (hPa)       0
# high Visibility (km)             2
# avg Visibility (km)              2
# low Visibility (km)              2
# high Wind (km/h)                 0
# avg Wind (km/h)                  0
# high Gust Wind (km/h)            0
# sum Precip. (mm)                 0
# Events                         139
# dtype: int64

# %%
#checking the high gust column
weather_df['high Gust Wind (km/h)']
# Out:
# 0       -
# 1       -
# 2       -
# 3       -
# 4       -
#        ..
# 360    58
# 361     -
# 362    47
# 363    55
# 364    63
# Name: high Gust Wind (km/h), Length: 365, dtype: object

# %%
#dropping the non-numeric columns from the dataframe
weather_df = weather_df.drop(columns=['high Gust Wind (km/h)', 'Events'])
# performing a linear interpolation
weather_df = weather_df.interpolate(method = 'linear')

# %%
weather_df.isnull().sum()
# Out:
# Date                           0
# high Temp. (°C)                0
# avg Temp. (°C)                 0
# low Temp. (°C)                 0
# high Dew Point (°C)            0
# avg Dew Point (°C)             0
# low Dew Point (°C)             0
# high Humidity (%)              0
# avg Humidity (%)               0
# low Humidity (%)               0
# high Sea Level Press. (hPa)    0
# avg Sea Level Press. (hPa)     0
# low Sea Level Press. (hPa)     0
# high Visibility (km)           0
# avg Visibility (km)            0
# low Visibility (km)            0
# high Wind (km/h)               0
# avg Wind (km/h)                0
# sum Precip. (mm)               0
# dtype: int64

# %%
# computing the correlation and plotting a heatmap using sns
cor = weather_df.corr()
cor
plt.figure(figsize=(15,10))
sns.heatmap(cor, cmap=plt.cm.Reds, annot=True)
plt.title('Correlation matrix for Weather variables')
plt.plot()
# Out:
# []

# %% [markdown]
# # Electricity Consumption Data

# %%
# reading from excel
elec_consumption_df = pd.read_excel('Historique_consommation_JOUR_2017.xls', skiprows=17)
elec_consumption_df
# Out:
#      Unnamed: 0  Unnamed: 1  Unnamed: 2        Date Type de données  \
# 0           NaN         NaN         NaN         NaN             NaN
# 1           NaN         NaN         NaN  01/01/2017     Définitives
# 2           NaN         NaN         NaN  02/01/2017     Définitives
# 3           NaN         NaN         NaN  03/01/2017     Définitives
# 4           NaN         NaN         NaN  04/01/2017     Définitives
# ..          ...         ...         ...         ...             ...
# 372         NaN         NaN         NaN  27/12/2017     Définitives
# 373         NaN         NaN         NaN  28/12/2017     Définitives
# 374         NaN         NaN         NaN  29/12/2017     Définitives
# 375         NaN         NaN         NaN  30/12/2017     Définitives
# 376         NaN         NaN         NaN  31/12/2017     Définitives
#
#      Energie journalière (MWh)
# 0                          NaN
# 1                    1652084.0
# 2                    1768332.0
# ...

# %%
# saving the dataframe as csv
elec_consumption_df.to_csv('Historique_consommation_JOUR_2017.csv', index = False)
elec_consumption_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 377 entries, 0 to 376
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 0 non-null      float64
#  1   Unnamed: 1                 0 non-null      float64
#  2   Unnamed: 2                 0 non-null      float64
#  3   Date                       365 non-null    object
#  4   Type de données            365 non-null    object
#  5   Energie journalière (MWh)  365 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 17.8+ KB

# %%
elec_consumption_df = pd.read_csv('Historique_consommation_JOUR_2017.csv', encoding ='utf-8-sig')
#checking for null values
elec_consumption_df.isnull().sum()
# Out:
# Unnamed: 0                   377
# Unnamed: 1                   377
# Unnamed: 2                   377
# Date                          12
# Type de données               12
# Energie journalière (MWh)     12
# dtype: int64

# %%
# dropping Unnecessary column
elec_consump_df = elec_consumption_df.drop(columns = ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2'])
elec_consump_df
# Out:
#            Date Type de données  Energie journalière (MWh)
# 0           NaN             NaN                        NaN
# 1    01/01/2017     Définitives                  1652084.0
# 2    02/01/2017     Définitives                  1768332.0
# 3    03/01/2017     Définitives                  1886120.0
# 4    04/01/2017     Définitives                  1923775.0
# ..          ...             ...                        ...
# 372  27/12/2017     Définitives                  1582970.0
# 373  28/12/2017     Définitives                  1664743.0
# 374  29/12/2017     Définitives                  1668623.0
# 375  30/12/2017     Définitives                  1437082.0
# 376  31/12/2017     Définitives                  1335348.0
#
# [377 rows x 3 columns]

# %%
elec_consump_df = elec_consump_df.dropna()
elec_consump_df.isnull().sum()
# Out:
# Date                         0
# Type de données              0
# Energie journalière (MWh)    0
# dtype: int64
