# %%
import warnings
# imporing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.distributions.empirical_distribution import ECDF
from statsmodels.tsa.stattools import acf, adfuller
from statsmodels.graphics.tsaplots import plot_acf
from arch.unitroot import VarianceRatio, ADF
import math
from statsmodels.tsa.arima.model import ARIMA 
from scipy.stats import norm
import numpy as np
from sklearn.metrics import mean_absolute_error 
from pmdarima import auto_arima
warnings.filterwarnings('ignore')

# %%
# read csv file
wind_df = pd.read_csv('WindGeneration.csv')
wind_df
# Out:
#             Date  Time  Wind Generation
# 0     01/01/2014     1           1190.1
# 1     01/01/2014     2           1186.6
# 2     01/01/2014     3           1174.3
# 3     01/01/2014     4           1146.7
# 4     01/01/2014     5           1156.8
# ...          ...   ...              ...
# 8755  31/12/2014    20            996.8
# 8756  31/12/2014    21           1031.8
# 8757  31/12/2014    22           1218.0
# 8758  31/12/2014    23           1312.1
# 8759  31/12/2014    24           1424.8
#
# [8760 rows x 3 columns]

# %%
wind_df.head(25)
# Out:
#           Date  Time  Wind Generation
# 0   01/01/2014     1           1190.1
# 1   01/01/2014     2           1186.6
# 2   01/01/2014     3           1174.3
# 3   01/01/2014     4           1146.7
# 4   01/01/2014     5           1156.8
# 5   01/01/2014     6           1189.7
# 6   01/01/2014     7           1175.4
# 7   01/01/2014     8           1089.8
# 8   01/01/2014     9            976.5
# 9   01/01/2014    10            966.4
# 10  01/01/2014    11            918.8
# 11  01/01/2014    12            779.6
# 12  01/01/2014    13            762.7
# 13  01/01/2014    14            790.1
# 14  01/01/2014    15            747.6
# 15  01/01/2014    16            734.6
# 16  01/01/2014    17            773.7
# 17  01/01/2014    18            927.3
# 18  01/01/2014    19           1115.3
# 19  01/01/2014    20           1236.0
# 20  01/01/2014    21           1357.0
# 21  01/01/2014    22           1481.5
# 22  01/01/2014    23           1615.7
# 23  01/01/2014    24           1779.2
# ...

# %%
#checking for null values
wind_df.isnull().sum()
# Out:
# Date               0
# Time               0
# Wind Generation    1
# dtype: int64

# %%
# linear interpolate nan values
wind_df.interpolate(method = 'linear',inplace =True)
wind_df.isnull().sum()
# Out:
# Date               0
# Time               0
# Wind Generation    0
# dtype: int64

# %%
# change the date column to datetime
wind_df['Date'] = pd.to_datetime(wind_df['Date'])
# time range from 0-23
wind_df['Time'] = wind_df['Time']-1
# Changing the time format
wind_df['Time'] = wind_df['Time'].apply(lambda x: '{:02}:00:00'.format(x))

# %%
# change the formatted time column  to datetime
wind_df['Time'] = pd.to_datetime(wind_df['Time'], format = '%H:%M:%S').dt.time
# combining the date and time column to timestamp column
wind_df['TimeStamp'] = [pd.datetime.combine(wind_df['Date'].iloc[i].date(), wind_df['Time'].iloc[i]) for i in range(wind_df.shape[0])]

# %%
wind_df = wind_df.set_index('TimeStamp')
wind_df
# Out:
#                           Date      Time  Wind Generation
# TimeStamp
# 2014-01-01 00:00:00 2014-01-01  00:00:00           1190.1
# 2014-01-01 01:00:00 2014-01-01  01:00:00           1186.6
# 2014-01-01 02:00:00 2014-01-01  02:00:00           1174.3
# 2014-01-01 03:00:00 2014-01-01  03:00:00           1146.7
# 2014-01-01 04:00:00 2014-01-01  04:00:00           1156.8
# ...                        ...       ...              ...
# 2014-12-31 19:00:00 2014-12-31  19:00:00            996.8
# 2014-12-31 20:00:00 2014-12-31  20:00:00           1031.8
# 2014-12-31 21:00:00 2014-12-31  21:00:00           1218.0
# 2014-12-31 22:00:00 2014-12-31  22:00:00           1312.1
# 2014-12-31 23:00:00 2014-12-31  23:00:00           1424.8
#
# [8760 rows x 3 columns]

# %%
# plotting the hourly timeseries
plt.figure(figsize=(15,10))
wind_df['Wind Generation'].plot()
plt.grid()
plt.title("Time Series")
plt.ylabel('Wind Generation')
plt.show()

# %%
# resampling daily data
daily_wind_df = wind_df.resample('D').mean()
daily_wind_df
# Out:
#             Wind Generation
# TimeStamp
# 2014-01-01      1094.641667
# 2014-01-02      1673.183333
# 2014-01-03        72.120833
# 2014-01-04       525.433333
# 2014-01-05       757.437500
# ...                     ...
# 2014-12-27       212.670833
# 2014-12-28       386.008333
# 2014-12-29       526.141667
# 2014-12-30      1033.745833
# 2014-12-31      1160.708333
#
# [365 rows x 1 columns]

# %%
# plotting the resampled daily data
plt.figure(figsize=(15,10))
daily_wind_df['Wind Generation'].plot()
plt.grid()
plt.title("Daily Time Series ")
plt.ylabel('Wind Generation')
plt.show()

# %%
# resampling weekly data and plotting
weekly_wind_df = wind_df.resample('W').mean()
plt.figure(figsize=(15,10))
weekly_wind_df['Wind Generation'].plot()
plt.grid()
plt.title("Weekly Time Series ")
plt.ylabel('Wind Generation')
plt.show()

# %%
# resampling monthly data and plotting
monthly_wind_df = wind_df.resample('M').mean()
plt.figure(figsize=(15,10))
monthly_wind_df['Wind Generation'].plot()
plt.grid()
plt.title("Monthly Time Series ")
plt.ylabel('Wind Generation')
plt.show()

# %%
# resampling quarterly data and plotting
quarterly_wind_df = wind_df.resample('Q').mean()
plt.figure(figsize=(15,10))
quarterly_wind_df['Wind Generation'].plot()
plt.grid()
plt.title("Quarterly Time Series ")
plt.ylabel('Wind Generation')
plt.show()

# %% [markdown]
# # change in wind generation over time

# %%
pct_changes = []

# computing the change as a percentage of the maximum wind generation
# iterating through each sample data for wind generation
for i in range(len(wind_df['Wind Generation'])-1):
    pct_change = ((wind_df['Wind Generation'].iloc[i+1] - wind_df['Wind Generation'].iloc[i]) /wind_df['Wind Generation'].max())* 100
    pct_changes.append(pct_change)
    
# padding the list as the number of values is less than the number of rows we have in the dataframe
padded_list = pct_changes + [np.nan] *(len(wind_df) - len(pct_changes))

# %%
wind_df['Pct_change'] = padded_list
wind_df
# Out:
#                           Date      Time  Wind Generation  Pct_change
# TimeStamp
# 2014-01-01 00:00:00 2014-01-01  00:00:00           1190.1   -0.108514
# 2014-01-01 01:00:00 2014-01-01  01:00:00           1186.6   -0.381348
# 2014-01-01 02:00:00 2014-01-01  02:00:00           1174.3   -0.855708
# 2014-01-01 03:00:00 2014-01-01  03:00:00           1146.7    0.313139
# 2014-01-01 04:00:00 2014-01-01  04:00:00           1156.8    1.020029
# ...                        ...       ...              ...         ...
# 2014-12-31 19:00:00 2014-12-31  19:00:00            996.8    1.085137
# 2014-12-31 20:00:00 2014-12-31  20:00:00           1031.8    5.772927
# 2014-12-31 21:00:00 2014-12-31  21:00:00           1218.0    2.917468
# 2014-12-31 22:00:00 2014-12-31  22:00:00           1312.1    3.494140
# 2014-12-31 23:00:00 2014-12-31  23:00:00           1424.8         NaN
#
# [8760 rows x 4 columns]

# %%
# plotting the Percentage of maximum generation
plt.figure(figsize=(15,10))
wind_df['Pct_change'].plot()
plt.grid()
plt.title("Time Series")
plt.ylabel('Percentage of maximum generation')
plt.show()

# %% [markdown]
# # CDF

# %%
# grouping positive ramps
positive_ramps = wind_df[wind_df['Pct_change']>=0].sort_values(by =['Pct_change'], ascending = True)
# grouping negative ramps
neg_ramps = wind_df[wind_df['Pct_change'] < 0]
#taking absolute value of the negative ramps
negative_ramps = abs(neg_ramps['Pct_change'])
# sorting the negative ramps
negative_ramps = negative_ramps.sort_values( ascending = True)

# %%
negative_ramps
# Out:
# TimeStamp
# 2014-03-06 06:00:00     0.003100
# 2014-05-24 05:00:00     0.003100
# 2014-03-12 21:00:00     0.003100
# 2014-03-31 07:00:00     0.003100
# 2014-06-27 04:00:00     0.003100
#                          ...
# 2014-09-22 17:00:00    14.348608
# 2014-03-16 00:00:00    14.618342
# 2014-03-11 21:00:00    16.664600
# 2014-11-08 19:00:00    16.825820
# 2014-10-26 02:00:00    33.130774
# Name: Pct_change, Length: 4374, dtype: float64

# %%
# computing the emperical cumulative distribution function for the -ve and +ve ramps
positive_cum = ECDF(positive_ramps['Pct_change'])
negative_cum = ECDF(negative_ramps)

# %%
# scatter plot the ECDF
plt.figure(figsize=(10,5))

# passing the positive an dnegative ramps as probability that sums upt o 1
plt.scatter(positive_cum.x, 1-positive_cum.y, label = 'ECDF for Positive ramps')
plt.scatter(-negative_cum.x, 1-negative_cum.y, label = 'ECDF Negative ramps')

# getting the cdf of positive and negative cdfs
x = np.linspace(0,30,30)
cdf_negative = norm.cdf(x, 0, np.std(negative_ramps))
cdf_positive = norm.cdf(x, 0, np.std(positive_ramps['Pct_change']))

# plot the cdf for both ramps using semilogy
plt.semilogy(x, 1-cdf_positive, label = 'CDF for positive ramps')
plt.semilogy(-x, 1-cdf_negative, label = 'CDF for negative ramps')

plt.xlabel('Wind power changes')
plt.ylabel('Cumulative probability')
plt.title('Hourly wind fluctuations ')
plt.legend()
plt.show()

# %% [markdown]
# # Computing Percentiles

# %%
# creating lists for the 4 percentiles
quantile_1 = []
quantile_5 = []
quantile_95 = []
quantile_99 = []

# for the range of differences getting the 4 percentile values of the wind generation percentage change
for d in range(1,25):
    pct_change = ((wind_df['Wind Generation'].shift(-1*d) - wind_df['Wind Generation'])/wind_df['Wind Generation'].max())*100
    quantile_1.append(pct_change.quantile([0.01]))
    quantile_5.append(pct_change.quantile([0.05]))
    quantile_95.append(pct_change.quantile([0.95]))
    quantile_99.append(pct_change.quantile([0.99]))

x = list(range(1,25))
# plotting the percentile values
plt.figure(figsize=(15,10))
plt.plot(x,quantile_1, label = "1 - percentile")
plt.plot(x,quantile_5, label = "5 - percentile")
plt.plot(x,quantile_95, label = "95 - percentile")
plt.plot(x,quantile_99, label = "99 - percentile")
plt.xlabel('Time scale')
plt.ylabel('Percentile Values')
plt.title('Plot for different Percentile values over timescale')
plt.legend()
plt.show()
